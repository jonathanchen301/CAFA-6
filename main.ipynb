# %% [markdown]
# # Imports

# %%
from src.process_sequences import fasta2df

import pandas as pd

# %% [markdown]
# # Sequence Processing

# %%
# train_sequences = fasta2df("./data/Train/train_sequences.fasta")
# test_sequences = fasta2df("./data/Test/testsuperset.fasta")

# # Save to CSV
# train_sequences.to_csv("./data/Train/train_sequences.csv", index=False)
# test_sequences.to_csv("./data/Test/test_sequences.csv", index=False)

# %%
# Loading
train_sequences = pd.read_csv("./data/Train/train_sequences.csv")
test_sequences = pd.read_csv("./data/Test/test_sequences.csv")

print("Total Train Sequences:", train_sequences.shape[0])
print("Total Test Sequences:", test_sequences.shape[0])
# Out:
# Total Train Sequences: 82404
# Total Test Sequences: 224309
